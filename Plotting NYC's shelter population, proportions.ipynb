# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
shelter = pd.read_csv('/Users/xiaolongl/Downloads/DHS_Daily_Report.csv',parse_dates = ["Date of Census"])

# %%
shelter.head()
# Out:
#   Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0     2015-01-02                    33162                      25018
# 1     2015-01-03                    33161                      25011
# 2     2015-01-04                    33303                      25027
# 3     2015-01-05                    33354                      25015
# 4     2015-01-06                    33374                      24978
#
#    Total Individuals in Shelter  Single Adult Men in Shelter  \
# 0                         58180                         8136
# 1                         58172                         8148
# 2                         58330                         8218
# 3                         58369                         8237
# 4                         58352                         8276
#
#    Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 0                           3100                           11236
# ...

# %%
shelter.plot(x = "Date of Census", y = "Total Individuals in Shelter")

# %%
shelter.plot(x = "Date of Census")

# %%
shelter.plot(x="Date of Census").legend(bbox_to_anchor=(1,1))

# %%
shelter["Total Adults in Shelter"]
# Out:
# 0       33162
# 1       33161
# 2       33303
# 3       33354
# 4       33374
#         ...
# 1971    36505
# 1972    36557
# 1973    36495
# 1974    36477
# 1975    36333
# Name: Total Adults in Shelter, Length: 1976, dtype: int64

# %%
shelter["Total Adults in Shelter"]/shelter["Total Individuals in Shelter"]
# Out:
# 0       0.569990
# 1       0.570051
# 2       0.570941
# 3       0.571433
# 4       0.571943
#           ...
# 1971    0.658270
# 1972    0.658839
# 1973    0.659207
# 1974    0.659203
# 1975    0.657599
# Length: 1976, dtype: float64

# %%
shelter["Proportion Adults"] = shelter["Total Adults in Shelter"]/shelter["Total Individuals in Shelter"]

# %%
shelter.head()
# Out:
#   Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0     2015-01-02                    33162                      25018
# 1     2015-01-03                    33161                      25011
# 2     2015-01-04                    33303                      25027
# 3     2015-01-05                    33354                      25015
# 4     2015-01-06                    33374                      24978
#
#    Total Individuals in Shelter  Single Adult Men in Shelter  \
# 0                         58180                         8136
# 1                         58172                         8148
# 2                         58330                         8218
# 3                         58369                         8237
# 4                         58352                         8276
#
#    Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 0                           3100                           11236
# ...

# %%
shelter.plot(x = "Date of Census", y = "Proportion Adults")

# %%
shelter["Proportion Children"] = shelter["Total Children in Shelter"]/shelter["Total Individuals in Shelter"]

# %%
shelter.head()
# Out:
#   Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0     2015-01-02                    33162                      25018
# 1     2015-01-03                    33161                      25011
# 2     2015-01-04                    33303                      25027
# 3     2015-01-05                    33354                      25015
# 4     2015-01-06                    33374                      24978
#
#    Total Individuals in Shelter  Single Adult Men in Shelter  \
# 0                         58180                         8136
# 1                         58172                         8148
# 2                         58330                         8218
# 3                         58369                         8237
# 4                         58352                         8276
#
#    Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 0                           3100                           11236
# ...

# %%
shelter.plot(x = "Date of Census", y = "Proportion Children")

# %%
shelter1["Proportion Single Men"] = shelter["Single Adult Men in Shelter"]/shelter["Total Individuals in Shelter"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ba9af25650db> in <module>
# ----> 1 shelter1["Proportion Single Men"] = shelter["Single Adult Men in Shelter"]/shelter["Total Individuals in Shelter"]
#
# NameError: name 'shelter1' is not defined

# %%
shelter["Proportion Single Men"] = shelter["Single Adult Men in Shelter"]/shelter["Total Individuals in Shelter"]

# %%
shelter.plot(x= "Date of Census", y = "Proportion Children")

# %%
shelter.plot(x= "Date of Census", y = "Proportion Single Men")

# %%
shelter["Proportion Single Men"] = shelter["Single Adult Women in Shelter"]/shelter["Total Individuals in Shelter"]

# %%
shelter.plot(x= "Date of Census", y = "Proportion Single Women")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Proportion Single Women'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-da9be13147e7> in <module>
# ...

# %%
shelter["Proportion Single Women"] = shelter["Single Adult Women in Shelter"]/shelter["Total Individuals in Shelter"]

# %%
shelter.plot(x= "Date of Census", y = "Proportion Single Women")
